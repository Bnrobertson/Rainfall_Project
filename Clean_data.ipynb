# %%
import pandas as pd

# %%
df = pd.read_csv("Rainfall_w_Humidity_new.csv")
df.head()
# Out:
#          time  tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun  \
# 0  2000-01-01  10.0   0.6  19.4   0.0   0.0    NaN   4.7   NaN  1024.3   NaN
# 1  2000-01-02  13.9   6.1  21.1   0.0   0.0    NaN  12.2   NaN  1023.5   NaN
# 2  2000-01-03  18.3  12.8  23.3   0.0   0.0  208.0  16.6   NaN  1021.0   NaN
# 3  2000-01-04  16.7  10.6  22.8   8.6   0.0  218.0  25.6   NaN  1012.0   NaN
# 4  2000-01-05   3.9  -2.8  10.6   0.0   0.0    NaN   9.4   NaN  1024.3   NaN
#
#    rain  hummax  humavg  hummin
# 0   0.0   100.0    73.6    40.0
# 1   0.0    86.0    73.2    56.0
# 2   0.0   100.0    81.9    51.0
# 3   1.0   100.0    84.2    59.0
# 4   0.0    92.0    57.5    37.0

# %%
df.tail()
# Out:
#             time  tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  \
# 8902  2024-05-16  27.4  22.2  33.9   0.0   NaN  351.0   5.2   NaN  1008.6
# 8903  2024-05-17  27.9  21.7  36.7  19.1   NaN  152.0   6.9   NaN  1012.2
# 8904         NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN     NaN
# 8905         NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN     NaN
# 8906         NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN     NaN
#
#       tsun  rain  hummax  humavg  hummin
# 8902   NaN   0.0    93.0    74.9    49.0
# 8903   NaN   1.0    90.0    77.8    56.0
# 8904   NaN   NaN     NaN     NaN     NaN
# 8905   NaN   NaN     NaN     NaN     NaN
# 8906   NaN   NaN     NaN     NaN     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8907 entries, 0 to 8906
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    8904 non-null   object
#  1   tavg    8902 non-null   float64
#  2   tmin    8904 non-null   float64
#  3   tmax    8904 non-null   float64
#  4   prcp    8904 non-null   float64
#  5   snow    8900 non-null   float64
#  6   wdir    4052 non-null   float64
#  7   wspd    8903 non-null   float64
#  8   wpgt    0 non-null      float64
#  9   pres    8870 non-null   float64
#  10  tsun    803 non-null    float64
#  11  rain    8904 non-null   float64
#  12  hummax  8871 non-null   float64
#  13  humavg  8871 non-null   float64
#  14  hummin  8871 non-null   float64
# dtypes: float64(14), object(1)
# memory usage: 1.0+ MB

# %%
df.dtypes
# Out:
# time       object
# tavg      float64
# tmin      float64
# tmax      float64
# prcp      float64
# snow      float64
# wdir      float64
# wspd      float64
# wpgt      float64
# pres      float64
# tsun      float64
# rain      float64
# hummax    float64
# humavg    float64
# hummin    float64
# dtype: object

# %%
df = df.drop(df.index[[8904, 8905, 8906]]).reset_index(drop=True)
df.tail()
# Out:
#             time  tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  \
# 8899  2024-05-13  18.8  10.6  26.7   0.0   0.0  133.0  10.4   NaN  1017.4
# 8900  2024-05-14  29.8  22.2  37.2   0.0   NaN  105.0  11.9   NaN  1011.9
# 8901  2024-05-15  28.4  22.8  35.0   0.0   NaN    0.0   4.7   NaN  1006.1
# 8902  2024-05-16  27.4  22.2  33.9   0.0   NaN  351.0   5.2   NaN  1008.6
# 8903  2024-05-17  27.9  21.7  36.7  19.1   NaN  152.0   6.9   NaN  1012.2
#
#       tsun  rain  hummax  humavg  hummin
# 8899   NaN   0.0    81.0    57.5    37.0
# 8900   NaN   0.0    93.0    85.3    63.0
# 8901   NaN   0.0    93.0    82.2    60.0
# 8902   NaN   0.0    93.0    74.9    49.0
# 8903   NaN   1.0    90.0    77.8    56.0

# %%
df.head()
# Out:
#          time  tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun  \
# 0  2000-01-01  10.0   0.6  19.4   0.0   0.0    NaN   4.7   NaN  1024.3   NaN
# 1  2000-01-02  13.9   6.1  21.1   0.0   0.0    NaN  12.2   NaN  1023.5   NaN
# 2  2000-01-03  18.3  12.8  23.3   0.0   0.0  208.0  16.6   NaN  1021.0   NaN
# 3  2000-01-04  16.7  10.6  22.8   8.6   0.0  218.0  25.6   NaN  1012.0   NaN
# 4  2000-01-05   3.9  -2.8  10.6   0.0   0.0    NaN   9.4   NaN  1024.3   NaN
#
#    rain  hummax  humavg  hummin
# 0   0.0   100.0    73.6    40.0
# 1   0.0    86.0    73.2    56.0
# 2   0.0   100.0    81.9    51.0
# 3   1.0   100.0    84.2    59.0
# 4   0.0    92.0    57.5    37.0

# %%
df["tavg"] = df["tavg"] * 9/5 + 32
df["tmin"] = df["tmin"] * 9/5 + 32
df["tmax"] = df["tmax"] * 9/5 + 32
df.head()
# Out:
#          time   tavg   tmin   tmax  prcp  snow   wdir  wspd  wpgt    pres  \
# 0  2000-01-01  50.00  33.08  66.92   0.0   0.0    NaN   4.7   NaN  1024.3
# 1  2000-01-02  57.02  42.98  69.98   0.0   0.0    NaN  12.2   NaN  1023.5
# 2  2000-01-03  64.94  55.04  73.94   0.0   0.0  208.0  16.6   NaN  1021.0
# 3  2000-01-04  62.06  51.08  73.04   8.6   0.0  218.0  25.6   NaN  1012.0
# 4  2000-01-05  39.02  26.96  51.08   0.0   0.0    NaN   9.4   NaN  1024.3
#
#    tsun  rain  hummax  humavg  hummin
# 0   NaN   0.0   100.0    73.6    40.0
# 1   NaN   0.0    86.0    73.2    56.0
# 2   NaN   0.0   100.0    81.9    51.0
# 3   NaN   1.0   100.0    84.2    59.0
# 4   NaN   0.0    92.0    57.5    37.0

# %%
df["prcp"] = df["prcp"] * 0.0393701
df.head()
# Out:
#          time   tavg   tmin   tmax      prcp  snow   wdir  wspd  wpgt    pres  \
# 0  2000-01-01  50.00  33.08  66.92  0.000000   0.0    NaN   4.7   NaN  1024.3
# 1  2000-01-02  57.02  42.98  69.98  0.000000   0.0    NaN  12.2   NaN  1023.5
# 2  2000-01-03  64.94  55.04  73.94  0.000000   0.0  208.0  16.6   NaN  1021.0
# 3  2000-01-04  62.06  51.08  73.04  0.338583   0.0  218.0  25.6   NaN  1012.0
# 4  2000-01-05  39.02  26.96  51.08  0.000000   0.0    NaN   9.4   NaN  1024.3
#
#    tsun  rain  hummax  humavg  hummin
# 0   NaN   0.0   100.0    73.6    40.0
# 1   NaN   0.0    86.0    73.2    56.0
# 2   NaN   0.0   100.0    81.9    51.0
# 3   NaN   1.0   100.0    84.2    59.0
# 4   NaN   0.0    92.0    57.5    37.0

# %%
df["pres"] = df["pres"] * 0.02953
df.head()
# Out:
#          time   tavg   tmin   tmax      prcp  snow   wdir  wspd  wpgt  \
# 0  2000-01-01  50.00  33.08  66.92  0.000000   0.0    NaN   4.7   NaN
# 1  2000-01-02  57.02  42.98  69.98  0.000000   0.0    NaN  12.2   NaN
# 2  2000-01-03  64.94  55.04  73.94  0.000000   0.0  208.0  16.6   NaN
# 3  2000-01-04  62.06  51.08  73.04  0.338583   0.0  218.0  25.6   NaN
# 4  2000-01-05  39.02  26.96  51.08  0.000000   0.0    NaN   9.4   NaN
#
#         pres  tsun  rain  hummax  humavg  hummin
# 0  30.247579   NaN   0.0   100.0    73.6    40.0
# 1  30.223955   NaN   0.0    86.0    73.2    56.0
# 2  30.150130   NaN   0.0   100.0    81.9    51.0
# 3  29.884360   NaN   1.0   100.0    84.2    59.0
# 4  30.247579   NaN   0.0    92.0    57.5    37.0

# %%
df = df.drop(["wpgt","tsun"], axis=1)
df.head()
# Out:
#          time   tavg   tmin   tmax      prcp  snow   wdir  wspd       pres  \
# 0  2000-01-01  50.00  33.08  66.92  0.000000   0.0    NaN   4.7  30.247579
# 1  2000-01-02  57.02  42.98  69.98  0.000000   0.0    NaN  12.2  30.223955
# 2  2000-01-03  64.94  55.04  73.94  0.000000   0.0  208.0  16.6  30.150130
# 3  2000-01-04  62.06  51.08  73.04  0.338583   0.0  218.0  25.6  29.884360
# 4  2000-01-05  39.02  26.96  51.08  0.000000   0.0    NaN   9.4  30.247579
#
#    rain  hummax  humavg  hummin
# 0   0.0   100.0    73.6    40.0
# 1   0.0    86.0    73.2    56.0
# 2   0.0   100.0    81.9    51.0
# 3   1.0   100.0    84.2    59.0
# 4   0.0    92.0    57.5    37.0
